# %%
with open("/content/drive/MyDrive/Discurso.txt") as archivo:
  discurso=archivo.read()

# %%
print(discurso[:500])
# Out:
# ... Queremos hablar clara y directamente en un lenguaje que todo el mundo pueda entender con facilidad. Todos hemos estado de acuerdo esta noche en que Estados Unidos tiene un problema muy serio. El problema que tiene Estados Unidos somos nosotros. Nosotros somos su problema. ...
#
# Así es, somos gente negra, los llamados negros; ciudadanos de segunda, ex-esclavos, Tú no eres más que un esclavo, no te gusta que te lo digan. Pero ¿qué otra cosa eres?, eres un ex-esclavo. No llegaste en el buque May

# %%
#funcion lend: medir la longitud del dato
len(discurso)
# Out:
# 4471

# %%
discurso = discurso.lower()
discurso = discurso.replace(",","")
discurso = discurso.replace(";","")
discurso = discurso.replace(".","")
discurso = discurso.replace(".","")
discurso = discurso.replace(":","")

# %%
len(discurso)
# Out:
# 4340

# %%
palabras = discurso.split()

# %%
palabras[:20]
# Out:
# ['queremos',
#  'hablar',
#  'clara',
#  'y',
#  'directamente',
#  'en',
#  'un',
#  'lenguaje',
#  'que',
#  'todo',
#  'el',
#  'mundo',
#  'pueda',
#  'entender',
#  'con',
#  'facilidad',
#  'todos',
#  'hemos',
#  'estado',
#  'de']

# %%
import pandas as pd
import numpy as np

palabras_array=np.array(palabras)

# %%
len(palabras_array)
# Out:
# 811

# %%
longitudes=np.array([len(palabra) for palabra in palabras_array])

print("promedio",np.mean(longitudes))
print("mediana",np.median(longitudes))
print("minimo",np.min(longitudes))
print("max",np.max(longitudes))
# Out:
# promedio 4.316892725030826
# mediana 4.0
# minimo 1
# max 12

# %%
df = pd.DataFrame(
    {
        "palabra":palabras
    }

)
df.head()
# Out:
#         palabra
# 0      queremos
# 1        hablar
# 2         clara
# 3             y
# 4  directamente

# %%
df["longitud"]=df["palabra"].str.len()
df.head(10)
# Out:
#         palabra  longitud
# 0      queremos         8
# 1        hablar         6
# 2         clara         5
# 3             y         1
# 4  directamente        12
# 5            en         2
# 6            un         2
# 7      lenguaje         8
# 8           que         3
# 9          todo         4

# %%
frecuencias=df["palabra"].value_counts()
print(frecuencias.head(20))
# Out:
# palabra
# el           37
# que          35
# en           25
# de           24
# negro        24
# amo          22
# del          19
# y            15
# la           15
# a            15
# los          14
# campo        12
# doméstico    12
# lo           12
# al            9
# decía         9
# casa          9
# “             9
# un            9
# te            8
# Name: count, dtype: int64

# %%
stopwords = [
    "el","que","en","de","del","y","la","a","los","lo","la","\"","un","te",
    "no","se","si","eso","para","le","una","su","o","“","es","son","por","más",
    "al","así","este","con"
]

# %%
df_limpio = df[~df["palabra"].isin(stopwords)]

# %%
frecuencias = df_limpio["palabra"].value_counts()
frecuencias.head(20)
# Out:
# palabra
# negro        24
# amo          22
# campo        12
# doméstico    12
# casa          9
# decía         9
# negros        8
# mismo         5
# mejor         5
# soy           4
# unidos        4
# estados       4
# tiempos       4
# eres          4
# odiaba        3
# dices         3
# tom           3
# único         3
# somos         3
# aquellos      3
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

texto_limpio = " ".join(df_limpio["palabra"])

wordcloud = WordCloud(width=1200, height=600, background_color="black").generate(texto_limpio)

plt.figure(figsize=(15,6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
